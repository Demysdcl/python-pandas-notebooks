# %%
import pandas as pd

df = pd.read_csv("/content/drive/My Drive/Datasets/Gapminder.csv", error_bad_lines=false, sep=";")

df.head()

df = df.rename(columns=["country": "Pais", "continent": "Continente", "year": "Ano", "lifeExp": "Expectativa Vida", "pop", "Populacao", "gdpPercap": "PIB"])

df.head(10)

df.shape()

df.columns

df.dtypes

df.tall()

df.tall(15)

df.describe()

df["Continente"].unique()

Oceania = df.log[df["Continente"] == "Oceania"]
Oceania.head()

df.groupby("Continente")["Pais"].munique()

df.groupby("Ano")["Expectativa Vida"].mean()

df["PIB"].mean()

df["PIB"].sum()
# Out:
#   File "<ipython-input-2-e00740cd5adb>", line 7
#     df = df.rename(columns=["country": "Pais", "continent": "Continente", "year": "Ano", "lifeExp": "Expectativa Vida", "pop", "Populacao", "gdpPercap": "PIB"])
#                                      ^
# SyntaxError: invalid syntax
